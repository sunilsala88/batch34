# %%
import pandas as pd
df=pd.read_csv('/Users/algo trading 2025/batch34/11_data analysis/unicorn.csv')
df
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df=df.set_index('Company')

# %%
df.loc['SHEIN','Date Joined']
# Out:
# '03-07-2018'

# %%
df.loc['Zopa','Year Founded']
# Out:
# np.int64(2005)

# %%
df.loc['SHEIN':'Stripe','Date Joined':'Industry']
# Out:
#         Date Joined                         Industry
# Company
# SHEIN    03-07-2018  E-commerce & direct-to-consumer
# Stripe   23-01-2014                          Fintech

# %%
df.loc['Zhaogang':'Zwift','Continent':'Funding']
# Out:
#                  Continent  Year Founded  Funding
# Company
# Zhaogang              Asia          2012    379.0
# Zhuan Zhuan           Asia          2015    990.0
# Zihaiguo              Asia          2018     80.0
# Zopa                Europe          2005    792.0
# Zwift        North America          2014    620.0

# %%
df.iloc[0,0]
# Out:
# np.int64(180)

# %%
df.iloc[-4,-5]
# Out:
# 'Beijing'

# %%
df.iloc[-3:,0:3]
# Out:
#           Valuation Date Joined                         Industry
# Company
# Zihaiguo          1  06-05-2021                Consumer & retail
# Zopa              1  19-10-2021                          Fintech
# Zwift             1  16-09-2020  E-commerce & direct-to-consumer

# %%
df.set_index('Company',inplace=True)

# %%
df.set_index('Industry',inplace=True )

# %%
df.reset_index()
# Out:
#           Company  Valuation Date Joined                         Industry  \
# 0       Bytedance        180  07-04-2017          Artificial intelligence
# 1          SpaceX        100  01-12-2012                            Other
# 2           SHEIN        100  03-07-2018  E-commerce & direct-to-consumer
# 3          Stripe         95  23-01-2014                          Fintech
# 4          Klarna         46  12-12-2011                          Fintech
# ...           ...        ...         ...                              ...
# 1069     Zhaogang          1  29-06-2017  E-commerce & direct-to-consumer
# 1070  Zhuan Zhuan          1  18-04-2017  E-commerce & direct-to-consumer
# 1071     Zihaiguo          1  06-05-2021                Consumer & retail
# 1072         Zopa          1  19-10-2021                          Fintech
# 1073        Zwift          1  16-09-2020  E-commerce & direct-to-consumer
#
#                City         Country      Continent  Year Founded  Funding
# ...

# %%
df
# Out:
#                                  Valuation Date Joined           City  \
# Industry
# Artificial intelligence                180  07-04-2017        Beijing
# Other                                  100  01-12-2012      Hawthorne
# E-commerce & direct-to-consumer        100  03-07-2018       Shenzhen
# Fintech                                 95  23-01-2014  San Francisco
# Fintech                                 46  12-12-2011      Stockholm
# ...                                    ...         ...            ...
# E-commerce & direct-to-consumer          1  29-06-2017       Shanghai
# E-commerce & direct-to-consumer          1  18-04-2017        Beijing
# Consumer & retail                        1  06-05-2021      Chongqing
# Fintech                                  1  19-10-2021         London
# E-commerce & direct-to-consumer          1  16-09-2020     Long Beach
#
#                                         Country      Continent  Year Founded  \
# Industry
# ...
